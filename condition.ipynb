# %%
if condition:
    statement
elif condition:
    statement
else:
    statement

# %%
mart="reliance"
cust="prasanna"
item="grc"
total_amt=1000
veg_amt=500
grc_amt=250
food_amt=250
if mart=="reliance":
    if cust=="swathi":
        if item=="veg":
            discount=0.50
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.20
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.15
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    elif cust=="bujji":
        if item=="veg":
            discount=0.40
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.25
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.35
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    elif cust=="shaheena":
        if item=="veg":
            discount=0.40
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.30
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.25
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    elif cust=="prasanna":
        if item=="veg":
            discount=0.30
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.10
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.05
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    else:
        print("no cust available")
elif mart=="jio":
    if cust=="swathi":
        if item=="veg":
            discount=0.40
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.40
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.25
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    elif cust=="bujji":
        if item=="veg":
            discount=0.25
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.30
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.35
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    elif cust=="shaheena":
        if item=="veg":
            discount=0.50
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.30
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.35
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    elif cust=="prasanna":
        if item=="veg":
            discount=0.20
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.10
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.05
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    else:
        print("no cust available")
else:
    print("no mart available")
# Out:
# after discount grc amount 225.0

# %%
mart="reliance"
cust="swathi"
item="grc"
total_amt=1000
veg_amt=500
grc_amt=250
food_amt=250
if mart=="reliance":
    if cust=="swathi":
        if item=="veg":
            discount=0.50
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.20
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.15
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    else:
        print("no customer available")
else:
    print("no mart is available")
# Out:
# after discount grc amount 200.0

# %%
mart_type=["reliance","jio"]
cust_type=["prasnna","bujji","shaheena","swathi"]
catagerios=["veg","grc","food"]
overall_amount=[500,250,250]
for mart in mart_type:
    if mart=="reliance":
        print("tihis is mart",mart)
        for cust in cust_type:
            if cust=="prasanna":
                print("this my name",cust)
                for item in catagerios:
                    print("this is item",item)
                    if item=="veg":
                        discount=0.30
                        after_discount=overall_amount[0]*discount
                        food_after=overall_amount-after_discount
                        print("after discount food amount",food_after)
                    else:
                        print("not availble")
# Out:
# tihis is mart reliance
