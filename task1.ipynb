# %%
customer_name="swathi"
order_food="papu tomato"
price=90
if customer_name=="bujji" and order_food=="lemon rice":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="curd rice":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="pongal":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="chiken":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="mutton":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="chiken biryani":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="pallav":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="fishcury":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="ladies finger":
    pdiscont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="chakra pongal":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="papu tomato":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="fried rice":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="chiken fry":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="bujji" and order_food=="egg biryani":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="lemon rice":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="curd rice":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="pongal":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="chiken":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="mutton":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="chiken biryani":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="pallav":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="fishcury":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="ladies finger":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="chakra pongal":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="papu tomato":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="fried rice":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="chiken fry":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="swathi" and order_food=="egg biryani":
    discont=price*.30
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="lemon rice":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="curd rice":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="pongal":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="chiken":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="mutton":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="chiken biryani":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="pallav":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="fishcury":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="ladies finger":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="chakra pongal":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="papu tomato":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="fried rice":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="chiken fry":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="prasanna" and order_food=="egg biryani":
    discont=price*.20
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="lemon rice":
    discont=price*.10
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="curd rice":
    discont=price*.10
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="pongal":
    discont=price*.10
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="chiken":
    discont=price*.10
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="mutton":
    discont=price*.10
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="chiken biryani":
    discont=price*.10
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="pallav":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="fishcury":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="ladies finger":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="chakra pongal":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="papu tomato":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="fried rice":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="chiken fry":
    discont=price*.40
    after=price-discont
    print("after",after)
elif customer_name=="others" and order_food=="egg biryani":
    discont=price*.40
    after=price-discont
    print("after",after)
else:
    print("not vailable")
# Out:
# after 63.0
