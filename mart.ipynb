# %%
mart="reliance"
cust="prasanna"
item="veg"
total_amt=1000
veg_amt=500
grc_amt=250
food_amt=250
if mart=="jio" and cust=="prasanna" and (item=="veg" or item=="grc" or item=="food"):
    print("prasanna purchased amount",total_amt)
    discount=veg_amt*0.20
    veg_after=veg_amt-discount
    print("after discount veg amount",veg_after)
    discount=grc_amt*0.10
    grc_after=grc_amt-discount
    print("after discount grc amount",grc_after)
    discount=food_amt*0.05
    food_after=food_amt-discount
    print("after discount food amount",food_after)
    after_discount=veg_after+grc_after+food_after
    print("after discount total amount",after_discount)
elif mart=="jio" and cust=="swathi" and (item=="veg" or item=="grc" or item=="food"):
    print("swathi purchased amount",total_amt)
    discount=veg_amt*0.40
    veg_after=veg_amt-discount
    print("after discount veg amount",veg_after)
    discount=grc_amt*0.40
    grc_after=grc_amt-discount
    print("after discount grc amount",grc_after)
    discount=food_amt*0.25
    food_after=food_amt-discount
    print("after discount food amount",food_after)
    after_discount=veg_after+grc_after+food_after
    print("after discount total amount",after_discount)
elif mart=="jio" and cust=="shaheena" and (item=="veg" or item=="grc" or item=="food"):
    print("shaheena purchased amount",total_amt)
    discount=veg_amt*0.50
    veg_after=veg_amt-discount
    print("after discount veg amount",veg_after)
    discount=grc_amt*0.30
    grc_after=grc_amt-discount
    print("after discount grc amount",grc_after)
    discount=food_amt*0.35
    food_after=food_amt-discount
    print("after discount food amount",food_after)
    after_discount=veg_after+grc_after+food_after
    print("after discount",after_discount)
elif mart=="reliance" and cust=="prasanna" and (item=="veg" or item=="grc" or item=="food"):
    print("prasanna purchased amount",total_amt)
    discount=veg_amt*0.30
    veg_after=veg_amt-discount
    print("after discount veg amount",veg_after)
    discount=grc_amt*0.10
    grc_after=grc_amt-discount
    print("after discount grc amount",grc_after)
    discount=food_amt*0.05
    food_after=food_amt-discount
    print("after discount food amount",food_after)
    after_discount=veg_after+grc_after+food_after
    print("after discount total",after_discount)
elif mart=="reliance" and cust=="swathi" and (item=="veg" or item=="grc" or item=="food"):
    print("swathi purchased amount",total_amt)
    discount=veg_amt*0.50
    veg_after=veg_amt-discount
    print("after discount veg amount",veg_after)
    discount=grc_amt*0.20
    grc_after=grc_amt-discount
    print("after discount grc amount",grc_after)
    discount=food_amt*0.15
    food_after=food_amt-discount
    print("after discount food amount",food_after)
    after_discount=veg_after+grc_after+food_after
    print("after discount total amount",after_discount)
elif mart=="reliance" and cust=="shaheena" and (item=="veg" or item=="grc" or item=="food"):
    print("shaheena purchased amount",total_amt)
    discount=veg_amt*0.40
    veg_after=veg_amt-discount
    print("after discount veg amount",veg_after)
    discount=grc_amt*0.20
    grc_after=grc_amt-discount
    print("after discount grc amount",grc_after)
    discount=food_amt*0.25
    food_after=food_amt-discount
    print("after discount food amount",food_after)
    after_discount=veg_after+grc_after+food_after
    print("after discount total amount",after_discount)
    
    
else:
    print("not available")
# Out:
# prasanna purchased amount 1000
# after discount veg amount 350.0
# after discount grc amount 225.0
# after discount food amount 237.5
# after discount total 812.5

# %%
mart="reliance"
cust="prasanna"
item="veg"
total_amt=1000
veg_amt=500
grc_amt=250
food_amt=250
if mart=="reliance":
    if cust=="swathi":
        if item=="veg":
            discount=0.50
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.20
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.15
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
        
    elif cust=="prasanna":
        if item=="veg":
            discount=0.30
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.10
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)  
        elif item=="food":
            discount=0.05
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    elif cust=="shaheena":
        if item=="veg":
            discount=0.40
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.20
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.25
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    else:
        print("no cust available")
elif mart=="jio":
    if cust=="swathi":
        if item=="veg":
            discount=0.40
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.40
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.25
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    elif cust=="prasanna":
        if item=="veg":
            discount=0.20
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.10
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.05
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")
    elif cust=="shaheena":
        if item=="veg":
            discount=0.50
            after_discount=veg_amt*discount
            veg_after=veg_amt-after_discount
            print("after discount veg amount",veg_after)
        elif item=="grc":
            discount=0.30
            after_discount=grc_amt*discount
            grc_after=grc_amt-after_discount
            print("after discount grc amount",grc_after)
        elif item=="food":
            discount=0.35
            after_discount=food_amt*discount
            food_after=food_amt-after_discount
            print("after discount food amount",food_after)
        else:
            print("no item available")        
    else:
        print("no cust available")
else:
    ("no mart available")
# Out:
# no item available

# %%
#loops and conditions:

# %%
mart_type=["reliance","jio"]
cust_type=["swathi","bujji","shaheena","prasanna"]
item_categories=["veg","grc","food"]
amounts=[500,250,250]

# %%
mart_type=["reliance","jio"]
for mart in mart_type:
    print("tis is my mart",mart)
# Out:
# tis is my mart reliance
# tis is my mart jio

# %%
mart_type=["reliance","jio"]
cust_type=["swathi","bujji","shaheena","prasanna"]
for mart in mart_type:
    print("This is my mart",mart)
    for cust in cust_type:
        print("customer name",cust)
# Out:
# This is my mart reliance
# customer name swathi
# customer name bujji
# customer name shaheena
# customer name prasanna
# This is my mart jio
# customer name swathi
# customer name bujji
# customer name shaheena
# customer name prasanna

# %%
mart_type=["reliance","jio"]
cust_type=["swathi","bujji","shaheena","prasanna"]
item_categories=["veg","grc","food"]
for mart in mart_type:
    print("This is my mart",mart)
    for cust in cust_type:
        print("customer name",cust)
        for item in item_categories:
            print("items",item)
# Out:
# This is my mart reliance
# customer name swathi
# items veg
# items grc
# items food
# customer name bujji
# items veg
# items grc
# items food
# customer name shaheena
# items veg
# items grc
# items food
# customer name prasanna
# items veg
# items grc
# items food
# This is my mart jio
# customer name swathi
# items veg
# items grc
# items food
# customer name bujji
# items veg
# items grc
# items food
# customer name shaheena
# items veg
# items grc
# items food
# customer name prasanna
# items veg
# items grc
# items food

# %%
mart_type=["reliance","jio"]
cust_type=["swathi","bujji","shaheena","prasanna"]
item_categories=["veg","grc","food"]
amounts=[1000,500,250]
for mart in mart_type:
    if mart=="reliance":
        print("this is my reliance")
        for cust in cust_type:
            if cust=="swathi":
                print("this is my name swathi")
                for item in item_categories:
                    print("this is items",item)
                    if item=="veg":
                        discount=0.30
                        after_discount=amounts[0]*discount
                        veg_after=amounts[0]-after_discount
                        print("after discount veg amount",veg_after)
                    elif item=="grc":
                        discount=0.10
                        after_discount=amounts[1]*discount
                        grc_after=amounts[1]-after_discount
                        print("after discount grc amount",grc_after)
                    elif item=="food":
                        discount=0.05
                        after_discount=amounts[2]*discount
                        food_after=amounts[2]-after_discount
                        print("after discount food amount",food_after)
                    else:
                        print("no item available")
# Out:
# this is my reliance
# this is my name swathi
# this is items veg
# after discount veg amount 700.0
# this is items grc
# after discount grc amount 450.0
# this is items food
# after discount food amount 237.5

# %%
mart_type=["reliance","jio"]
cust_type=["swathi","bujji","shaheena","prasanna"]
item_categories=["veg","grc","food"]
amounts=[1000,500,250]
for mart in mart_type:
    if mart=="reliance":
        print("this is my reliance")
        for cust in cust_type:
            if cust=="swathi":
                print("this is my name ",cust)
                for item in item_categories:
                    print("this is items",item)
            elif cust=="shaheena":
                print("this is my name ",cust)
                for item in item_categories:
                    print("this is items",item)
            elif cust=="bujji":
                print("this is my name ",cust)
                for item in item_categories:
                    print("this is items",item)
            elif cust=="prasanna":
                print("this is my name ",cust)
                for item in item_categories:
                    print("this is items",item)
# Out:
# this is my reliance
# this is my name  swathi
# this is items veg
# this is items grc
# this is items food
# this is my name  bujji
# this is items veg
# this is items grc
# this is items food
# this is my name  shaheena
# this is items veg
# this is items grc
# this is items food
# this is my name  prasanna
# this is items veg
# this is items grc
# this is items food

# %%
mart_type=["reliance","jio"]
cust_type=["swathi","bujji","shaheena","prasanna"]
item_categories=["veg","grc","food"]
amounts=[1000,500,250]
for mart in mart_type:
    if mart=="reliance":
        print("****---this is my mart***---",mart)
        for cust in cust_type:
            if cust=="swathi":
                print("___this is my name___",cust)
                for item in item_categories:
                    print("__-this is items___",item)
                    if item=="veg":
                        discount=0.30
                        after_discount=amounts[0]*discount
                        veg_after=amounts[0]-after_discount
                        print("___after discount veg amount___",veg_after)
                    elif item=="grc":
                        discount=0.10
                        after_discount=amounts[1]*discount
                        grc_after=amounts[1]-after_discount
                        print("___after discount grc amount___",grc_after)
                    elif item=="food":
                        discount=0.05
                        after_discount=amounts[2]*discount
                        food_after=amounts[2]-after_discount
                        print("___after discount food amount____",food_after)
                    else:
                        print("no item available")
            elif cust=="shaheena":
                print("____this is my name____",cust)
                for item in item_categories:
                    print("____this is items____",item)
                    if item=="veg":
                        discount=0.30
                        after_discount=amounts[0]*discount
                        veg_after=amounts[0]-after_discount
                        print("___after discount veg amount___",veg_after)
                    elif item=="grc":
                        discount=0.10
                        after_discount=amounts[1]*discount
                        grc_after=amounts[1]-after_discount
                        print("___after discount grc amount_____",grc_after)
                    elif item=="food":
                        discount=0.05
                        after_discount=amounts[2]*discount
                        food_after=amounts[2]-after_discount
                        print("___after discount food amount____",food_after)
                    else:
                        print("no item available")
            elif cust=="bujji":
                print("this is my name",cust)
                for item in item_categories:
                    print("___this is items___",item)
                    if item=="veg":
                        discount=0.30
                        after_discount=amounts[0]*discount
                        veg_after=amounts[0]-after_discount
                        print("____after discount veg amount____",veg_after)
                    elif item=="grc":
                        discount=0.10
                        after_discount=amounts[1]*discount
                        grc_after=amounts[1]-after_discount
                        print("____after discount grc amount____",grc_after)
                    elif item=="food":
                        discount=0.05
                        after_discount=amounts[2]*discount
                        food_after=amounts[2]-after_discount
                        print("___after discount food amount___",food_after)
                    else:
                        print("no item available")
            elif cust=="prasanna":
                print("___this is my name____",cust)
                for item in item_categories:
                    print("____this is items____",item)
                    if item=="veg":
                        discount=0.30
                        after_discount=amounts[0]*discount
                        veg_after=amounts[0]-after_discount
                        print("____after discount veg amount_____",veg_after)
                    elif item=="grc":
                        discount=0.10
                        after_discount=amounts[1]*discount
                        grc_after=amounts[1]-after_discount
                        print("____after discount grc amount_____",grc_after)
                    elif item=="food":
                        discount=0.05
                        after_discount=amounts[2]*discount
                        food_after=amounts[2]-after_discount
                        print("_____after discount food amount____",food_after)
                    else:
                        print("no item available")
            else:
                print("no cust available")
    elif mart=="jio":
        print("******-----this is my mart--------****",mart)
        for cust in cust_type:
            if cust=="swathi":
                print("____this is my name____",cust)
                for item in item_categories:
                    print("____this is items_____",item)
                    if item=="veg":
                        discount=0.30
                        after_discount=amounts[0]*discount
                        veg_after=amounts[0]-after_discount
                        print("_____after discount veg amount___",veg_after)
                    elif item=="grc":
                        discount=0.10
                        after_discount=amounts[1]*discount
                        grc_after=amounts[1]-after_discount
                        print("____after discount grc amount____",grc_after)
                    elif item=="food":
                        discount=0.05
                        after_discount=amounts[2]*discount
                        food_after=amounts[2]-after_discount
                        print("_____after discount food amount____",food_after)
                    else:
                        print("no item available")
            elif cust=="shaheena":
                print("____this is my name____",cust)
                for item in item_categories:
                    print("___this is items___",item)
                    if item=="veg":
                        discount=0.30
                        after_discount=amounts[0]*discount
                        veg_after=amounts[0]-after_discount
                        print("___after discount veg amount___",veg_after)
                    elif item=="grc":
                        discount=0.10
                        after_discount=amounts[1]*discount
                        grc_after=amounts[1]-after_discount
                        print("___after discount grc amount___",grc_after)
                    elif item=="food":
                        discount=0.05
                        after_discount=amounts[2]*discount
                        food_after=amounts[2]-after_discount
                        print("___after discount food amount___",food_after)
                    else:
                        print("no item available")
            elif cust=="bujji":
                print("___this is my name___",cust)
                for item in item_categories:
                    print("___this is items____",item)
                    if item=="veg":
                        discount=0.30
                        after_discount=amounts[0]*discount
                        veg_after=amounts[0]-after_discount
                        print("___after discount veg amount___",veg_after)
                    elif item=="grc":
                        discount=0.10
                        after_discount=amounts[1]*discount
                        grc_after=amounts[1]-after_discount
                        print("___after discount grc amount___",grc_after)
                    elif item=="food":
                        discount=0.05
                        after_discount=amounts[2]*discount
                        food_after=amounts[2]-after_discount
                        print("___after discount food amount____",food_after)
                    else:
                        print("no item available")
            elif cust=="prasanna":
                print("____this is my name___",cust)
                for item in item_categories:
                    print("____this is items___",item)
                    if item=="veg":
                        discount=0.30
                        after_discount=amounts[0]*discount
                        veg_after=amounts[0]-after_discount
                        print("____after discount veg amount____",veg_after)
                    elif item=="grc":
                        discount=0.10
                        after_discount=amounts[1]*discount
                        grc_after=amounts[1]-after_discount
                        print("___after discount grc amount___",grc_after)
                    elif item=="food":
                        discount=0.05
                        after_discount=amounts[2]*discount
                        food_after=amounts[2]-after_discount
                        print("____after discount food amount____",food_after)
                    else:
                        print("no item available")
            else:
                print("no cust available")
# Out:
# ****---this is my mart***--- reliance
# ___this is my name___ swathi
# __-this is items___ veg
# ___after discount veg amount___ 700.0
# __-this is items___ grc
# ___after discount grc amount___ 450.0
# __-this is items___ food
# ___after discount food amount____ 237.5
# this is my name bujji
# ___this is items___ veg
# ____after discount veg amount____ 700.0
# ___this is items___ grc
# ____after discount grc amount____ 450.0
# ___this is items___ food
# ___after discount food amount___ 237.5
# ____this is my name____ shaheena
# ____this is items____ veg
# ___after discount veg amount___ 700.0
# ____this is items____ grc
# ___after discount grc amount_____ 450.0
# ____this is items____ food
# ___after discount food amount____ 237.5
# ___this is my name____ prasanna
# ____this is items____ veg
# ____after discount veg amount_____ 700.0
# ____this is items____ grc
# ____after discount grc amount_____ 450.0
# ____this is items____ food
# _____after discount food amount____ 237.5
# ...
