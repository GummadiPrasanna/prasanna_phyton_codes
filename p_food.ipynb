# %%
# p_food=["tamoto_rice","lemon_rice","curd_rice","vegitable_biryani","chicken_biryani","mutton_biryani","egg_briyani","egg_fried_rice","chiken_fried_rice","prawns_biryani"]
# p_customer=["gopal","srinivasarao","sujatha","veeraswamy","venkateswaramma","meghana","mamatha","pavitra","deepthi","sravani"]
# type_of_customer=["husband","mother_side_famimly","motherilla_side_family","brothers/cusions","sisters/cusions","others"]
# overall_amount=[300,350,250,400,500,900,400,150,200,700]

# %%
# conditions

# %%
p_food="mutton_biryani"
p_customer="meghana"
if p_food=="tamoto_rice" and p_customer=="gopal":
    print(p_food,"delivery to",p_customer)
elif p_food=="lemon_rice" and p_customer=="srinivasarao":
    print(p_food,"delivery to",p_customer)
elif p_food=="curd_rice" and p_customer=="sujatha":
    print(p_food,"delivery to",p_customer)
elif p_food=="vegitable_biryani" and p_customer=="veeraswamy":
    print(p_food,"delivery to",p_customer)
elif p_food=="chicken_biryani" and p_customer=="venkateswaramma":
    print(p_food,"delivery to",p_customer)
elif p_food=="mutton_biryani" and p_customer=="meghana":
    print(p_food,"delivery to",p_customer)
elif p_food=="egg_briyani" and p_customer=="mamatha":
    print(p_food,"delivery to",p_customer)
elif p_food=="egg_fried_rice" and p_customer=="pavitra":
    print(p_food,"delivery to",p_customer)
elif p_food=="chiken_fried_rice" and p_customer=="deepthi":
    print(p_food,"delivery to",p_customer)
elif p_food=="prawns_biryani" and p_customer=="sravani":
    print(p_food,"delivery to",p_customer)
else:
    print("no customer and no item available")

# %%
#loops

# %%
p_food=["tamoto_rice","lemon_rice","curd_rice","vegitable_biryani","chicken_biryani","mutton_biryani","egg_briyani","egg_fried_rice","chiken_fried_rice","prawns_biryani"]
def P_food_delivery(p_food):
    for food in p_food:
        print("----my food items----",food)
        if food=="tamoto_rice":
            print("****delivery to meghana***",food)
        elif food=="lemon_rice":
            print("****delivary to mamatha****",food)
        elif food=="curd_rice":
            print("****delivary to sujatha****",food)
        elif food=="vegitable_biryani":
            print("****delivary to pavitra****",food)
        elif food=="chicken_biryani":
            print("****delivary to deepthi****",food)
        elif food=="mutton_biryani":
            print("****delivary to gopal****",food)
        elif food=="egg_briyani":
            print("****delivary to venkateswaramma****",food)
        elif food=="egg_fried_rice":
            print("****delivary to veeraswamny****",food)
        elif food=="chiken_fried_rice":
            print("****delivary to srinivasarao****",food)
        elif food=="prawns_biryani":
            print("****delivary to sravani****",food)
        else:
            print("no customer available")

# %%
P_food_delivery(p_food)
# Out:
# ----my food items---- tamoto_rice
# ****delivery to meghana*** tamoto_rice
# ----my food items---- lemon_rice
# ****delivary to mamatha**** lemon_rice
# ----my food items---- curd_rice
# ****delivary to sujatha**** curd_rice
# ----my food items---- vegitable_biryani
# ****delivary to pavitra**** vegitable_biryani
# ----my food items---- chicken_biryani
# ****delivary to deepthi**** chicken_biryani
# ----my food items---- mutton_biryani
# ****delivary to gopal**** mutton_biryani
# ----my food items---- egg_briyani
# ****delivary to venkateswaramma**** egg_briyani
# ----my food items---- egg_fried_rice
# ****delivary to veeraswamny**** egg_fried_rice
# ----my food items---- chiken_fried_rice
# ****delivary to srinivasarao**** chiken_fried_rice
# ----my food items---- prawns_biryani
# ****delivary to sravani**** prawns_biryani

# %%
# type_of_customer=["husband","mother_side_famimly","motherilla_side_family","brothers/cusions","sisters/cusions","others"]
# p_customer=["gopal","srinivasarao","sujatha","veeraswamy","venkateswaramma","meghana","mamatha","pavitra","deepthi","sravani"]
# p_food=["tamoto_rice","lemon_rice","curd_rice","vegitable_biryani","chicken_biryani","mutton_biryani","egg_briyani","egg_fried_rice","chiken_fried_rice","prawns_biryani"]
# overall_amount=[300,350,250,400,500,900,400,150,200,700]

# %%
type_of_customer="others"
p_customer="sujatha"
p_food="lemon_rice"
overall_amount=[300,350,250,400,500,900,400,150,200,700]
if type_of_customer=="husband":
    print("my customer type",type_of_customer)
    if p_customer=="gopal":
        print("my customer name",p_customer)
        if p_food=="tamoto_rice":
            discount=0.00
            after_discount=overall_amount[0]*discount
            print("--------tamoto_rice after_discount---------",after_discount)
        elif p_food=="lemon_rice":
            discount=0.00
            after_discount=overall_amount[1]*discount
            print("---------lemon_rice after_discount-------",after_discount)
        elif p_food=="curd_rice":
            discount=0.00
            after_discount=overall_amount[2]*discount
            print("------curd_rice after_discount-------",after_discount)
        elif p_food=="vegitable_biryani":
            discount=0.00
            after_discount=overall_amount[3]*discount
            print("-----vegitable_biryani after_discount-------",after_discount)
        elif p_food=="chicken_biryani":
            discount=0.00
            after_discount=overall_amount[4]*discount
            print("---------chicken_biryani after_discount----------",after_discount)
        elif p_food=="mutton_biryani":
            discount=0.00
            after_discount=overall_amount[5]*discount
            print("----------mutton_biryani after_discount----------",after_discount)
        elif p_food=="egg_briyani":
            discount=0.00
            after_discount=overall_amount[6]*discount
            print("-----------egg_briyani after_discount------------",after_discount)
        elif p_food=="egg_fried_rice":
            discount=0.00
            after_discount=overall_amount[7]*discount
            print("----------egg_fried_rice after_discount-----------",after_discount)
        elif p_food=="chiken_fried_rice":
            discount=0.00
            after_discount=overall_amount[8]*discount
            print("-----------chiken_fried_rice after_discount---------",after_discount)
        elif p_food=="prawns_biryani":
            discount=0.00
            after_discount=overall_amount[9]*discount
            print("-------------prawns_biryani after_discount----------",after_discount)
        else:
            print("^^^^^ no food item available ^^^^^^^^")
    else:
        print("no customer available")
elif type_of_customer=="mother_side_famimly":
    print("my customer type",type_of_customer)
    if (p_customer=="srinivasarao" or p_customer=="sujatha") :
        print("my customer name",p_customer)
        if p_food=="tamoto_rice":
            discount=0.50
            after_discount=overall_amount[0]*discount
            print("tamoto_rice after_discount",after_discount)
            after_tamota_rice_disc=overall_amount[0]-after_discount
            print("after_tamota_rice_disc",after_tamota_rice_disc)
        elif p_food=="lemon_rice":
            discount=0.50
            after_discount=overall_amount[1]*discount
            print("lemon_rice after_discount",after_discount)
            after_lemon_rice_disc=overall_amount[1]-after_discount
            print("after_lemon_rice_disc",after_lemon_rice_disc)
        elif p_food=="curd_rice":
            discount=0.50
            after_discount=overall_amount[2]*discount
            print("curd_rice after_discount",after_discount)
            after_curd_rice_disc=overall_amount[2]-after_discount
            print("after_curd_rice_disc",after_curd_rice_disc)
        elif p_food=="vegitable_biryani":
            discount=0.50
            after_discount=overall_amount[3]*discount
            print("vegitable_biryani after_discount",after_discount)
            after_vegitable_br_disc=overall_amount[3]-after_discount
            print("after_vegitable_br_disc",after_vegitable_br_disc)
        elif p_food=="chicken_biryani":
            discount=0.50
            after_discount=overall_amount[4]*discount
            print("chicken_biryani after_discount",after_discount)
            after_chiken_br_disc=overall_amount[4]-after_discount
            print("after_chiken_br_disc",after_chiken_br_disc)
        elif p_food=="mutton_biryani":
            discount=0.50
            after_discount=overall_amount[5]*discount
            print("mutton_biryani after_discount",after_discount)
            after_mutton_br_disc=overall_amount[5]-after_discount
            print("after_mutton_br_disc",after_mutton_br_disc)
        elif p_food=="egg_briyani":
            discount=0.50
            after_discount=overall_amount[6]*discount
            print("egg_briyani after_discount",after_discount)
            after_egg_br_disc=overall_amount[6]-after_discount
            print("after_egg_br_disc",after_egg_br_disc)
        elif p_food=="egg_fried_rice":
            discount=0.50
            after_discount=overall_amount[7]*discount
            print("egg_fried_rice after_discount",after_discount)
            after_egg_fried_rice_disc=overall_amount[7]-after_discount
            print("after_egg_fried_rice_disc",after_egg_fried_rice_disc)
        elif p_food=="chiken_fried_rice":
            discount=0.50
            after_discount=overall_amount[8]*discount
            print("chiken_fried_rice after_discount",after_discount)
            after_chiken_fried_rice_disc=overall_amount[8]-after_discount
            print("after_chiken_fried_rice_disc",after_chiken_fried_rice_disc)
        elif p_food=="prawns_biryani":
            discount=0.50
            after_discount=overall_amount[9]*discount
            print("prawns_biryani after_discount",after_discount)
            after_prawns_br_disc=overall_amount[9]-after_discount
            print("after_prawns_br_disc",after_prawns_br_disc)
        else:
             print("no food item available")
    else:
        print("no customer available")
elif type_of_customer=="motherilla_side_family":
    print("my customer type",type_of_customer)
    if (p_customer=="veeraswamy" or p_customer=="venkateswaramma"):
        print("my customer name",p_customer)
        if p_food=="tamoto_rice":
            discount=0.40
            after_discount=overall_amount[0]*discount
            print("tamoto_rice after_discount",after_discount)
            after_tamota_rice_disc=overall_amount[0]-after_discount
            print("after_tamota_rice_disc",after_tamota_rice_disc)
        elif p_food=="lemon_rice":
            discount=0.40
            after_discount=overall_amount[1]*discount
            print("lemon_rice after_discount",after_discount)
            after_lemon_rice_disc=overall_amount[1]-after_discount
            print("after_lemon_rice_disc",after_lemon_rice_disc)
        elif p_food=="curd_rice":
            discount=0.40
            after_discount=overall_amount[2]*discount
            print("curd_rice after_discount",after_discount)
            after_curd_rice_disc=overall_amount[2]-after_discount
            print("after_curd_rice_disc",after_curd_rice_disc)
        elif p_food=="vegitable_biryani":
            discount=0.40
            after_discount=overall_amount[3]*discount
            print("vegitable_biryani after_discount",after_discount)
            after_vegitable_br_disc=overall_amount[3]-after_discount
            print("after_vegitable_br_disc",after_vegitable_br_disc)
        elif p_food=="chicken_biryani":
            discount=0.40
            after_discount=overall_amount[4]*discount
            print("chicken_biryani after_discount",after_discount)
            after_chiken_br_disc=overall_amount[4]-after_discount
            print("after_chiken_br_disc",after_chiken_br_disc)
        elif p_food=="mutton_biryani":
            discount=0.40
            after_discount=overall_amount[5]*discount
            print("mutton_biryani after_discount",after_discount)
            after_mutton_br_disc=overall_amount[5]-after_discount
            print("after_mutton_br_disc",after_mutton_br_disc)
        elif p_food=="egg_briyani":
            discount=0.40
            after_discount=overall_amount[6]*discount
            print("egg_briyani after_discount",after_discount)
            after_egg_br_disc=overall_amount[6]-after_discount
            print("after_egg_br_disc",after_egg_br_disc)
        elif p_food=="egg_fried_rice":
            discount=0.40
            after_discount=overall_amount[7]*discount
            print("egg_fried_rice after_discount",after_discount)
            after_egg_fried_rice_disc=overall_amount[7]-after_discount
            print("after_egg_fried_rice_disc",after_egg_fried_rice_disc)
        elif p_food=="chiken_fried_rice":
            discount=0.40
            after_discount=overall_amount[8]*discount
            print("chiken_fried_rice after_discount",after_discount)
            after_chiken_fried_rice_disc=overall_amount[8]-after_discount
            print("after_chiken_fried_rice_disc",after_chiken_fried_rice_disc)
        elif p_food=="prawns_biryani":
            discount=0.40
            after_discount=overall_amount[9]*discount
            print("prawns_biryani after_discount",after_discount)
            after_prawns_br_disc=overall_amount[9]-after_discount
            print("after_prawns_br_disc",after_prawns_br_disc)
        else:
            print("no food item available")
    else:
        print("no customer available")
elif type_of_customer=="brothers/cusions":
    print("my customer type",type_of_customer)
    if p_customer=="brother":
        print("my customer name",p_customer)
        if p_food=="tamoto_rice":
            discount=0.60
            after_discount=overall_amount[0]*discount
            print("tamoto_rice after_discount",after_discount)
            after_tamota_rice_disc=overall_amount[0]-after_discount
            print("after_tamota_rice_disc",after_tamota_rice_disc)
        elif p_food=="lemon_rice":
            discount=0.60
            after_discount=overall_amount[1]*discount
            print("lemon_rice after_discount",after_discount)
            after_lemon_rice_disc=overall_amount[1]-after_discount
            print("after_lemon_rice_disc",after_lemon_rice_disc)
        elif p_food=="curd_rice":
            discount=0.60
            after_discount=overall_amount[2]*discount
            print("curd_rice after_discount",after_discount)
            after_curd_rice_disc=overall_amount[2]-after_discount
            print("after_curd_rice_disc",after_curd_rice_disc)
        elif p_food=="vegitable_biryani":
            discount=0.60
            after_discount=overall_amount[3]*discount
            print("vegitable_biryani after_discount",after_discount)
            after_vegitable_br_disc=overall_amount[3]-after_discount
            print("after_vegitable_br_disc",after_vegitable_br_disc)
        elif p_food=="chicken_biryani":
            discount=0.60
            after_discount=overall_amount[4]*discount
            print("chicken_biryani after_discount",after_discount)
            after_chiken_br_disc=overall_amount[4]-after_discount
            print("after_chiken_br_disc",after_chiken_br_disc)
        elif p_food=="mutton_biryani":
            discount=0.60
            after_discount=overall_amount[5]*discount
            print("mutton_biryani after_discount",after_discount)
            after_mutton_br_disc=overall_amount[5]-after_discount
            print("after_mutton_br_disc",after_mutton_br_disc)
        elif p_food=="egg_briyani":
            discount=0.60
            after_discount=overall_amount[6]*discount
            print("egg_briyani after_discount",after_discount)
            after_egg_br_disc=overall_amount[6]-after_discount
            print("after_egg_br_disc",after_egg_br_disc)
        elif p_food=="egg_fried_rice":
            discount=0.60
            after_discount=overall_amount[7]*discount
            print("egg_fried_rice after_discount",after_discount)
            after_egg_fried_rice_disc=overall_amount[7]-after_discount
            print("after_egg_fried_rice_disc",after_egg_fried_rice_disc)
        elif p_food=="chiken_fried_rice":
            discount=0.60
            after_discount=overall_amount[8]*discount
            print("chiken_fried_rice after_discount",after_discount)
            after_chiken_fried_rice_disc=overall_amount[8]-after_discount
            print("after_chiken_fried_rice_disc",after_chiken_fried_rice_disc)
        elif p_food=="prawns_biryani":
            discount=0.60
            after_discount=overall_amount[9]*discount
            print("prawns_biryani after_discount",after_discount)
            after_prawns_br_disc=overall_amount[9]-after_discount
            print("after_prawns_br_disc",after_prawns_br_disc)
        else:
            print("no food item available")
    else:
        print("no customer available")
elif type_of_customer=="sisters/cusions":
    print("my customer type",type_of_customer)
    if p_customer=="sravani":
        print("my customer name",p_customer)
        if p_food=="tamoto_rice":
            discount=0.60
            after_discount=overall_amount[0]*discount
            print("tamoto_rice after_discount",after_discount)
            after_tamota_rice_disc=overall_amount[0]-after_discount
            print("after_tamota_rice_disc",after_tamota_rice_disc)
        elif p_food=="lemon_rice":
            discount=0.60
            after_discount=overall_amount[1]*discount
            print("lemon_rice after_discount",after_discount)
            after_lemon_rice_disc=overall_amount[1]-after_discount
            print("after_lemon_rice_disc",after_lemon_rice_disc)
        elif p_food=="curd_rice":
            discount=0.60
            after_discount=overall_amount[2]*discount
            print("curd_rice after_discount",after_discount)
            after_curd_rice_disc=overall_amount[2]-after_discount
            print("after_curd_rice_disc",after_curd_rice_disc)
        elif p_food=="vegitable_biryani":
            discount=0.60
            after_discount=overall_amount[3]*discount
            print("vegitable_biryani after_discount",after_discount)
            after_vegitable_br_disc=overall_amount[3]-after_discount
            print("after_vegitable_br_disc",after_vegitable_br_disc)
        elif p_food=="chicken_biryani":
            discount=0.60
            after_discount=overall_amount[4]*discount
            print("chicken_biryani after_discount",after_discount)
            after_chiken_br_disc=overall_amount[4]-after_discount
            print("after_chiken_br_disc",after_chiken_br_disc)
        elif p_food=="mutton_biryani":
            discount=0.60
            after_discount=overall_amount[5]*discount
            print("mutton_biryani after_discount",after_discount)
            after_mutton_br_disc=overall_amount[5]-after_discount
            print("after_mutton_br_disc",after_mutton_br_disc)
        elif p_food=="egg_briyani":
            discount=0.60
            after_discount=overall_amount[6]*discount
            print("egg_briyani after_discount",after_discount)
            after_egg_br_disc=overall_amount[6]-after_discount
            print("after_egg_br_disc",after_egg_br_disc)
        elif p_food=="egg_fried_rice":
            discount=0.60
            after_discount=overall_amount[7]*discount
            print("egg_fried_rice after_discount",after_discount)
            after_egg_fried_rice_disc=overall_amount[7]-after_discount
            print("after_egg_fried_rice_disc",after_egg_fried_rice_disc)
        elif p_food=="chiken_fried_rice":
            discount=0.60
            after_discount=overall_amount[8]*discount
            print("chiken_fried_rice after_discount",after_discount)
            after_chiken_fried_rice_disc=overall_amount[8]-after_discount
            print("after_chiken_fried_rice_disc",after_chiken_fried_rice_disc)
        elif p_food=="prawns_biryani":
            discount=0.60
            after_discount=overall_amount[9]*discount
            print("prawns_biryani after_discount",after_discount)
            after_prawns_br_disc=overall_amount[9]-after_discount
            print("after_prawns_br_disc",after_prawns_br_disc)
        else:
            print("no food item available")
    else:
        print("no customer available")
elif type_of_customer=="others":
    print("my customer type",type_of_customer)
    if (p_customer=="meghana" or p_customer=="mamatha" or p_customer=="pavitra" or p_customer=="deepthi"):
        print("my customer name",p_customer)
        if p_food=="tamoto_rice":
            discount=0.20
            after_discount=overall_amount[0]*discount
            print("tamoto_rice after_discount",after_discount)
            after_tamota_rice_disc=overall_amount[0]-after_discount
            print("after_tamota_rice_disc",after_tamota_rice_disc)
        elif p_food=="lemon_rice":
            discount=0.20
            after_discount=overall_amount[1]*discount
            print("lemon_rice after_discount",after_discount)
            after_lemon_rice_disc=overall_amount[1]-after_discount
            print("after_lemon_rice_disc",after_lemon_rice_disc)
        elif p_food=="curd_rice":
            discount=0.20
            after_discount=overall_amount[2]*discount
            print("curd_rice after_discount",after_discount)
            after_curd_rice_disc=overall_amount[2]-after_discount
            print("after_curd_rice_disc",after_curd_rice_disc)
        elif p_food=="vegitable_biryani":
            discount=0.20
            after_discount=overall_amount[3]*discount
            print("vegitable_biryani after_discount",after_discount)
            after_vegitable_br_disc=overall_amount[3]-after_discount
            print("after_vegitable_br_disc",after_vegitable_br_disc)
        elif p_food=="chicken_biryani":
            discount=0.20
            after_discount=overall_amount[4]*discount
            print("chicken_biryani after_discount",after_discount)
            after_chiken_br_disc=overall_amount[4]-after_discount
            print("after_chiken_br_disc",after_chiken_br_disc)
        elif p_food=="mutton_biryani":
            discount=0.20
            after_discount=overall_amount[5]*discount
            print("mutton_biryani after_discount",after_discount)
            after_mutton_br_disc=overall_amount[5]-after_discount
            print("after_mutton_br_disc",after_mutton_br_disc)
        elif p_food=="egg_briyani":
            discount=0.20
            after_discount=overall_amount[6]*discount
            print("egg_briyani after_discount",after_discount)
            after_egg_br_disc=overall_amount[6]-after_discount
            print("after_egg_br_disc",after_egg_br_disc)
        elif p_food=="egg_fried_rice":
            discount=0.20
            after_discount=overall_amount[7]*discount
            print("egg_fried_rice after_discount",after_discount)
            after_egg_fried_rice_disc=overall_amount[7]-after_discount
            print("after_egg_fried_rice_disc",after_egg_fried_rice_disc)
        elif p_food=="chiken_fried_rice":
            discount=0.20
            after_discount=overall_amount[8]*discount
            print("chiken_fried_rice after_discount",after_discount)
            after_chiken_fried_rice_disc=overall_amount[8]-after_discount
            print("after_chiken_fried_rice_disc",after_chiken_fried_rice_disc)
        elif p_food=="prawns_biryani":
            discount=0.20
            after_discount=overall_amount[9]*discount
            print("prawns_biryani after_discount",after_discount)
            after_prawns_br_disc=overall_amount[9]-after_discount
            print("after_prawns_br_disc",after_prawns_br_disc)
        else:
            print("no food item available")
    else:
        print("no customer available")
# Out:
# my customer type others
# no customer available
